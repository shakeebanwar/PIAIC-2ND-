# %%
import numpy as np

# %%
import pandas as pd

# %%
import os
a=os.listdir('.') #dot means us hi root pa
a
# Out:
# ['.git',
#  '.ipynb_checkpoints',
#  'abc.txt',
#  'abc.xml',
#  'allData.csv',
#  'AllTask.csv',
#  'Book1.xlsx',
#  'class-6.ipynb',
#  'data.json',
#  'index.html',
#  'mydata.csv',
#  'mydata.sqlite',
#  'Pandas Ch 6.ipynb',
#  'QwBoPu.xlsx',
#  'store.h5',
#  'Task_1.docx',
#  'TAXRATES1.csv']

# %%
pd.read_csv('E:/TAXRATES1.csv')
# Out:
#    Unnamed: 0 State ZipCode      TaxRegionName  StateRate  \
# 0           0    AK     one  ANCHORAGE BOROUGH        0.0
# 1           1    AK     one  ANCHORAGE BOROUGH        0.0
# 2           2    AK     two  ANCHORAGE BOROUGH        0.0
# 3           3    AK     two  ANCHORAGE BOROUGH        NaN
#
#    EstimatedCombinedRate  EstimatedCountyRate  EstimatedCityRate  \
# 0                    0.0                  0.0                NaN
# 1                    NaN                  0.0                0.0
# 2                    0.0                  NaN                0.0
# 3                    0.0                  0.0                0.0
#
#    EstimatedSpecialRate  RiskLevel
# 0                   0.0          1
# 1                   0.0          2
# 2                   NaN          3
# 3                   0.0          4

# %%
pd.read_csv('TAXRATES1.csv', na_values=[0]) #0 agr file ma hoga tu nan kardaga
#na_values m jo bhi data do agar exist krta ho to to wo null m conevrt krdeta hai
# Out:
#    Unnamed: 0 State ZipCode      TaxRegionName  StateRate  \
# 0         NaN    AK     one  ANCHORAGE BOROUGH        NaN
# 1         1.0    AK     one  ANCHORAGE BOROUGH        NaN
# 2         2.0    AK     two  ANCHORAGE BOROUGH        NaN
# 3         3.0    AK     two  ANCHORAGE BOROUGH        NaN
#
#    EstimatedCombinedRate  EstimatedCountyRate  EstimatedCityRate  \
# 0                    NaN                  NaN                NaN
# 1                    NaN                  NaN                NaN
# 2                    NaN                  NaN                NaN
# 3                    NaN                  NaN                NaN
#
#    EstimatedSpecialRate  RiskLevel
# 0                   NaN          1
# 1                   NaN          2
# 2                   NaN          3
# 3                   NaN          4

# %%
pd.read_csv('TAXRATES1.csv', na_values=[0,'one'])
# jitna argument donga agar file ma hoga tu null kardaga
#na_values m jo bhi data do agar exist krta ho to to wo null m conevrt krdeta hai
# Out:
#    Unnamed: 0 State ZipCode      TaxRegionName  StateRate  \
# 0         NaN    AK     NaN  ANCHORAGE BOROUGH        NaN
# 1         1.0    AK     NaN  ANCHORAGE BOROUGH        NaN
# 2         2.0    AK     two  ANCHORAGE BOROUGH        NaN
# 3         3.0    AK     two  ANCHORAGE BOROUGH        NaN
#
#    EstimatedCombinedRate  EstimatedCountyRate  EstimatedCityRate  \
# 0                    NaN                  NaN                NaN
# 1                    NaN                  NaN                NaN
# 2                    NaN                  NaN                NaN
# 3                    NaN                  NaN                NaN
#
#    EstimatedSpecialRate  RiskLevel
# 0                   NaN          1
# 1                   NaN          2
# 2                   NaN          3
# 3                   NaN          4

# %%
pd.read_csv('TAXRATES1.csv', skiprows=[1]) #row skip ka liya use
# Out:
#    Unnamed: 0 State ZipCode      TaxRegionName  StateRate  \
# 0           1    AK     one  ANCHORAGE BOROUGH        0.0
# 1           2    AK     two  ANCHORAGE BOROUGH        0.0
# 2           3    AK     two  ANCHORAGE BOROUGH        NaN
#
#    EstimatedCombinedRate  EstimatedCountyRate  EstimatedCityRate  \
# 0                    NaN                  0.0                  0
# 1                    0.0                  NaN                  0
# 2                    0.0                  0.0                  0
#
#    EstimatedSpecialRate  RiskLevel
# 0                   0.0          2
# 1                   NaN          3
# 2                   0.0          4

# %%
pd.read_csv('TAXRATES1.csv',skipfooter=1) #row skip ka liya use 1 ma last ka 1
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   """Entry point for launching an IPython kernel.
#    Unnamed: 0 State ZipCode      TaxRegionName  StateRate  \
# 0           0    AK     one  ANCHORAGE BOROUGH          0
# 1           1    AK     one  ANCHORAGE BOROUGH          0
# 2           2    AK     two  ANCHORAGE BOROUGH          0
#
#    EstimatedCombinedRate  EstimatedCountyRate  EstimatedCityRate  \
# 0                    0.0                  0.0                NaN
# 1                    NaN                  0.0                0.0
# 2                    0.0                  NaN                0.0
#
#    EstimatedSpecialRate  RiskLevel
# 0                   0.0          1
# 1                   0.0          2
# 2                   NaN          3

# %%
pd.read_csv('data.csv') #row skip ka liya use 1 ma last ka 1
# Out:
#         Course  Students         location  Faculty Teachers
# 0           AI      3000       Saylani HO                30
# 1          CNC      1056  Saylani Gulshan                14
# 2  Block chain      1307          Adamjee                12
# 3          IOT      2000           Bahria                16

# %%
pd.read_csv('data.csv',skiprows=[0]) #row skip ka liya use 1 ma last ka 1  remove nhi karta igonore karta ha
# Out:
#             AI  3000       Saylani HO  30
# 0          CNC  1056  Saylani Gulshan  14
# 1  Block chain  1307          Adamjee  12
# 2          IOT  2000           Bahria  16

# %%
pd.options.display.max_rows = 10 # display maximum 10 rows in output
pd.read_csv('TAXRATES1.csv')
# Out:
#    Unnamed: 0 State ZipCode      TaxRegionName  StateRate  \
# 0           0    AK     one  ANCHORAGE BOROUGH        0.0
# 1           1    AK     one  ANCHORAGE BOROUGH        0.0
# 2           2    AK     two  ANCHORAGE BOROUGH        0.0
# 3           3    AK     two  ANCHORAGE BOROUGH        NaN
#
#    EstimatedCombinedRate  EstimatedCountyRate  EstimatedCityRate  \
# 0                    0.0                  0.0                NaN
# 1                    NaN                  0.0                0.0
# 2                    0.0                  NaN                0.0
# 3                    0.0                  0.0                0.0
#
#    EstimatedSpecialRate  RiskLevel
# 0                   0.0          1
# 1                   0.0          2
# 2                   NaN          3
# 3                   0.0          4

# %%
pd.read_csv('TAXRATES1.csv', nrows=2) # load 2 rows data from file with header
# Out:
#    Unnamed: 0 State ZipCode      TaxRegionName  StateRate  \
# 0           0    AK     one  ANCHORAGE BOROUGH          0
# 1           1    AK     one  ANCHORAGE BOROUGH          0
#
#    EstimatedCombinedRate  EstimatedCountyRate  EstimatedCityRate  \
# 0                    0.0                    0                NaN
# 1                    NaN                    0                0.0
#
#    EstimatedSpecialRate  RiskLevel
# 0                     0          1
# 1                     0          2

# %%
chunkread = pd.read_csv('allTask.csv', chunksize=2) # To read a file in pieces, specify a chunksize as a number of rows
for i in chunkread:
    print(i)
    print('--------------------------------------')
# Out:
#   Unnamed: 0 Unnamed: 1     Unnamed: 2 Unnamed: 3             Unnamed: 4  \
# 0      State    ZipCode  TaxRegionName  StateRate  EstimatedCombinedRate
# 1         AL      35004          MOODY   0.040000               0.100000
#
#             Unnamed: 5         Unnamed: 6            Unnamed: 7      State
# 0  EstimatedCountyRate  EstimatedCityRate  EstimatedSpecialRate  RiskLevel
# 1                    0           0.040000              0.020000          2
# --------------------------------------
#   Unnamed: 0  Unnamed: 1        Unnamed: 2  Unnamed: 3  Unnamed: 4  \
# 2         AL       35005        ADAMSVILLE        0.04        0.10
# 3         AL       35006  JEFFERSON COUNTY        0.04        0.06
#
#    Unnamed: 5  Unnamed: 6  Unnamed: 7  State
# 2        0.01        0.04        0.01      1
# 3        0.01        0.00        0.01      2
# --------------------------------------
#   Unnamed: 0  Unnamed: 1 Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# ...

# %%
import pandas as pd

# %%
chunkread = pd.read_csv('allTask.csv', chunksize=10) # To read a file in pieces, specify a chunksize as a number of rows
for i in chunkread:
    print(i)
    print('--------------------------------------') #chunk 10 means 10 rows ak baar ma
# Out:
#   Unnamed: 0 Unnamed: 1        Unnamed: 2 Unnamed: 3             Unnamed: 4  \
# 0      State    ZipCode     TaxRegionName  StateRate  EstimatedCombinedRate
# 1         AL      35004             MOODY   0.040000               0.100000
# 2         AL      35005        ADAMSVILLE   0.040000               0.100000
# 3         AL      35006  JEFFERSON COUNTY   0.040000               0.060000
# 4         AL      35007         ALABASTER   0.040000               0.090000
# 5         AL      35010         ALEXANDER   0.040000               0.100000
# 6         AL      35011         ALEXANDER   0.040000               0.100000
# 7         AL      35013           ALLGOOD   0.040000               0.100000
# 8         AL      35014  TALLADEGA COUNTY   0.040000               0.070000
# 9         AL      35015          IRONDALE   0.040000               0.100000
#
#             Unnamed: 5         Unnamed: 6            Unnamed: 7      State
# ...

# %%
chunkread = pd.read_csv('allTask.csv', chunksize=10,nrows=100) # To read a file in pieces, specify a chunksize as a number of rows
for i in chunkread:
    print(i)
    print('--------------------------------------') #chunk 10 means 10 rows ak baar ma
# Out:
#   Unnamed: 0 Unnamed: 1        Unnamed: 2 Unnamed: 3             Unnamed: 4  \
# 0      State    ZipCode     TaxRegionName  StateRate  EstimatedCombinedRate
# 1         AL      35004             MOODY   0.040000               0.100000
# 2         AL      35005        ADAMSVILLE   0.040000               0.100000
# 3         AL      35006  JEFFERSON COUNTY   0.040000               0.060000
# 4         AL      35007         ALABASTER   0.040000               0.090000
# 5         AL      35010         ALEXANDER   0.040000               0.100000
# 6         AL      35011         ALEXANDER   0.040000               0.100000
# 7         AL      35013           ALLGOOD   0.040000               0.100000
# 8         AL      35014  TALLADEGA COUNTY   0.040000               0.070000
# 9         AL      35015          IRONDALE   0.040000               0.100000
#
#             Unnamed: 5         Unnamed: 6            Unnamed: 7      State
# ...

# %%
chunkread = pd.read_csv('allTask.csv', chunksize=11,nrows=100) # To read a file in pieces, specify a chunksize as a number of rows
for i in chunkread:
    print(i)
    print('--------------------------------------') #chunk 11 means 11 rows ak baar ma jo bacha ga uska 1 chunk ban jaega
# Out:
#    Unnamed: 0 Unnamed: 1          Unnamed: 2 Unnamed: 3  \
# 0       State    ZipCode       TaxRegionName  StateRate
# 1          AL      35004               MOODY   0.040000
# 2          AL      35005          ADAMSVILLE   0.040000
# 3          AL      35006    JEFFERSON COUNTY   0.040000
# 4          AL      35007           ALABASTER   0.040000
# 5          AL      35010           ALEXANDER   0.040000
# 6          AL      35011           ALEXANDER   0.040000
# 7          AL      35013             ALLGOOD   0.040000
# 8          AL      35014    TALLADEGA COUNTY   0.040000
# 9          AL      35015            IRONDALE   0.040000
# 10         AL      35016  ARAB (MARSHALL CO)   0.040000
#
#                Unnamed: 4           Unnamed: 5         Unnamed: 6  \
# 0   EstimatedCombinedRate  EstimatedCountyRate  EstimatedCityRate
# 1                0.100000                    0           0.040000
# 2                0.100000             0.010000           0.040000
# ...

# %%
pd.read_csv('allTask.csv', skiprows=[0],delimiter=",")
# Out:
#       State ZipCode       TaxRegionName StateRate EstimatedCombinedRate  \
# 0        AL   35004               MOODY  0.040000              0.100000
# 1        AL   35005          ADAMSVILLE  0.040000              0.100000
# 2        AL   35006    JEFFERSON COUNTY  0.040000              0.060000
# 3        AL   35007           ALABASTER  0.040000              0.090000
# 4        AL   35010           ALEXANDER  0.040000              0.100000
# 5        AL   35011           ALEXANDER  0.040000              0.100000
# 6        AL   35013             ALLGOOD  0.040000              0.100000
# 7        AL   35014    TALLADEGA COUNTY  0.040000              0.070000
# 8        AL   35015            IRONDALE  0.040000              0.100000
# 9        AL   35016  ARAB (MARSHALL CO)  0.040000              0.090000
# 10       AL   35019      CULLMAN COUNTY  0.040000              0.085000
# 11       AL   35020            BESSEMER  0.040000              0.100000
# ...

# %%
import csv
# For any file with a single-character delimiter, you can use Python’s built-in csv module.
# To use it, pass any open file or file-like object to csv.reader:
f = open('TAXRATES1.csv')
reader = csv.reader(f)
# reader = list(csv.reader(f)) # Without loop
reader
#reader direct print nhi hoga iterate karwana hoga

# %%
for line in reader:
    print(line) #haar row ko array ma
# Out:
# ['', 'State', 'ZipCode', 'TaxRegionName', 'StateRate', 'EstimatedCombinedRate', 'EstimatedCountyRate', 'EstimatedCityRate', 'EstimatedSpecialRate', 'RiskLevel']
# ['0', 'AK', 'one', 'ANCHORAGE BOROUGH', '0', '0', '0', '', '0', '1']
# ['1', 'AK', 'one', 'ANCHORAGE BOROUGH', '0', '', '0', '0', '0', '2']
# ['2', 'AK', 'two', 'ANCHORAGE BOROUGH', '0', '0', '', '0', '', '3']
# ['3', 'AK', 'two', 'ANCHORAGE BOROUGH', '', '0', '0', '0', '0', '4']

# %%
import csv
# For any file with a single-character delimiter, you can use Python’s built-in csv module.
# To use it, pass any open file or file-like object to csv.reader:
f = open('data.csv')
reader = csv.reader(f)
# reader = list(csv.reader(f)) # Without loop
reader #ya abhi sirf pointer bana ha
#reader direct print nhi hoga iterate karwana hoga
list(reader) #asa bi hojae ga
# Out:
# [['Course', 'Students', 'location', 'Faculty Teachers'],
#  ['AI', '3000', 'Saylani HO', '30'],
#  ['CNC', '1056', 'Saylani Gulshan', '14'],
#  ['Block chain', '1307', 'Adamjee', '12'],
#  ['IOT', '2000', 'Bahria', '16']]

# %%
for line in reader:
    print(line) #haar row ko array ma
# Out:
# ['Course', 'Students', 'location', 'Faculty Teachers']
# ['AI', '3000', 'Saylani HO', '30']
# ['CNC', '1056', 'Saylani Gulshan', '14']
# ['Block chain', '1307', 'Adamjee', '12']
# ['IOT', '2000', 'Bahria', '16']

# %%
range(1,10) # 1 to 9 isliye nhi aye q ka iterate karna higa
# Out:
# range(1, 10)

# %%
list(range(1,10)) # loop sa bi ho sakta ha
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
with open('data.csv') as f:
    lines = list(csv.reader(f))
lines #for loop wala kam
# Out:
# [['Course', 'Students', 'location', 'Faculty Teachers'],
#  ['AI', '3000', 'Saylani HO', '30'],
#  ['CNC', '1056', 'Saylani Gulshan', '14'],
#  ['Block chain', '1307', 'Adamjee', '12'],
#  ['IOT', '2000', 'Bahria', '16']]

# %%
with open('allData.csv') as f:
    lines = list(csv.reader(f))
lines #for loop wala kam
# Out:
# [['',
#   'EstimatedCombinedRate',
#   'from_postcode',
#   'state',
#   'to_postcode_ taxrate'],
#  ['0', '0.0', '99501', 'AK', '99927'],
#  ['1', '0.0', '19701', 'DE', '19980'],
#  ['2', '0.03', '99547', 'AK', '99840'],
#  ['3', '0.04', '99554', 'AK', '99832'],
#  ['4', '0.04', '80116', 'CO', '80135'],
#  ['5', '0.04', '96708', 'HI', '96793'],
#  ['6', '0.05', '99555', 'AK', '99921'],
#  ['7', '0.05', '35032', 'AL', '36866'],
#  ['8', '0.05', '80126', 'CO', '80163'],
#  ['9', '0.02', '99557', 'AK', '99841'],
#  ['10', '0.06', '99559', 'AK', '99922'],
#  ['11', '0.06', '35006', 'AL', '36853'],
#  ['12', '0.06', '20001', 'DC', '88888'],
#  ['13', '0.06', '34423', 'FL', '34487'],
#  ['14', '0.06', '30003', 'GA', '31144'],
#  ['15', '0.06', '50007', 'IA', '52351'],
#  ['16', '0.06', '83201', 'ID', '83877'],
#  ['17', '0.035', '99591', 'AK', '99660'],
#  ['18', '0.0785', '99603', 'AK', '99603'],
#  ['19', '0.0785', '86403', 'AZ', '86442'],
#  ['20', '0.0785', '62002', 'IL', '62269'],
# ...

# %%
import csv
# For any file with a single-character delimiter, you can use Python’s built-in csv module.
# To use it, pass any open file or file-like object to csv.reader:
f = open('allData.csv')
reader = csv.reader(f)
# reader = list(csv.reader(f)) # Without loop

#reader direct print nhi hoga iterate karwana hoga
list(reader) #asa bi hojae ga
# Out:
# [['',
#   'EstimatedCombinedRate',
#   'from_postcode',
#   'state',
#   'to_postcode_ taxrate'],
#  ['0', '0.0', '99501', 'AK', '99927'],
#  ['1', '0.0', '19701', 'DE', '19980'],
#  ['2', '0.03', '99547', 'AK', '99840'],
#  ['3', '0.04', '99554', 'AK', '99832'],
#  ['4', '0.04', '80116', 'CO', '80135'],
#  ['5', '0.04', '96708', 'HI', '96793'],
#  ['6', '0.05', '99555', 'AK', '99921'],
#  ['7', '0.05', '35032', 'AL', '36866'],
#  ['8', '0.05', '80126', 'CO', '80163'],
#  ['9', '0.02', '99557', 'AK', '99841'],
#  ['10', '0.06', '99559', 'AK', '99922'],
#  ['11', '0.06', '35006', 'AL', '36853'],
#  ['12', '0.06', '20001', 'DC', '88888'],
#  ['13', '0.06', '34423', 'FL', '34487'],
#  ['14', '0.06', '30003', 'GA', '31144'],
#  ['15', '0.06', '50007', 'IA', '52351'],
#  ['16', '0.06', '83201', 'ID', '83877'],
#  ['17', '0.035', '99591', 'AK', '99660'],
#  ['18', '0.0785', '99603', 'AK', '99603'],
#  ['19', '0.0785', '86403', 'AZ', '86442'],
#  ['20', '0.0785', '62002', 'IL', '62269'],
# ...

# %%
import csv
# For any file with a single-character delimiter, you can use Python’s built-in csv module.
# To use it, pass any open file or file-like object to csv.reader:
f = open('allData.csv')
reader = csv.reader(f)
# reader = list(csv.reader(f)) # Without loop
reader

# %%
for i in reader:
    print(i)
# Out:
# ['', 'EstimatedCombinedRate', 'from_postcode', 'state', 'to_postcode_ taxrate']
# ['0', '0.0', '99501', 'AK', '99927']
# ['1', '0.0', '19701', 'DE', '19980']
# ['2', '0.03', '99547', 'AK', '99840']
# ['3', '0.04', '99554', 'AK', '99832']
# ['4', '0.04', '80116', 'CO', '80135']
# ['5', '0.04', '96708', 'HI', '96793']
# ['6', '0.05', '99555', 'AK', '99921']
# ['7', '0.05', '35032', 'AL', '36866']
# ['8', '0.05', '80126', 'CO', '80163']
# ['9', '0.02', '99557', 'AK', '99841']
# ['10', '0.06', '99559', 'AK', '99922']
# ['11', '0.06', '35006', 'AL', '36853']
# ['12', '0.06', '20001', 'DC', '88888']
# ['13', '0.06', '34423', 'FL', '34487']
# ['14', '0.06', '30003', 'GA', '31144']
# ['15', '0.06', '50007', 'IA', '52351']
# ['16', '0.06', '83201', 'ID', '83877']
# ['17', '0.035', '99591', 'AK', '99660']
# ['18', '0.0785', '99603', 'AK', '99603']
# ['19', '0.0785', '86403', 'AZ', '86442']
# ['20', '0.0785', '62002', 'IL', '62269']
# ['21', '0.07', '99615', 'AK', '99929']
# ...

# %%
pd.read_csv('allData.csv')
# Out:
#      Unnamed: 0  EstimatedCombinedRate  from_postcode state  \
# 0             0                0.00000          99501    AK
# 1             1                0.00000          19701    DE
# 2             2                0.03000          99547    AK
# 3             3                0.04000          99554    AK
# 4             4                0.04000          80116    CO
# 5             5                0.04000          96708    HI
# 6             6                0.05000          99555    AK
# 7             7                0.05000          35032    AL
# 8             8                0.05000          80126    CO
# 9             9                0.02000          99557    AK
# 10           10                0.06000          99559    AK
# 11           11                0.06000          35006    AL
# 12           12                0.06000          20001    DC
# 13           13                0.06000          34423    FL
# 14           14                0.06000          30003    GA
# ...

# %%
pd.read_csv('allData.csv',skiprows=[1])
# Out:
#      Unnamed: 0  EstimatedCombinedRate  from_postcode state  \
# 0             1                0.00000          19701    DE
# 1             2                0.03000          99547    AK
# 2             3                0.04000          99554    AK
# 3             4                0.04000          80116    CO
# 4             5                0.04000          96708    HI
# 5             6                0.05000          99555    AK
# 6             7                0.05000          35032    AL
# 7             8                0.05000          80126    CO
# 8             9                0.02000          99557    AK
# 9            10                0.06000          99559    AK
# 10           11                0.06000          35006    AL
# 11           12                0.06000          20001    DC
# 12           13                0.06000          34423    FL
# 13           14                0.06000          30003    GA
# 14           15                0.06000          50007    IA
# ...

# %%
pd.options.display.max_rows = 10 # display maximum 10 rows in output
pd.read_csv('allData.csv')
# Out:
#      Unnamed: 0  EstimatedCombinedRate  from_postcode state  \
# 0             0                 0.0000          99501    AK
# 1             1                 0.0000          19701    DE
# 2             2                 0.0300          99547    AK
# 3             3                 0.0400          99554    AK
# 4             4                 0.0400          80116    CO
# ..          ...                    ...            ...   ...
# 253         253                 0.0827          81521    CO
# 254         254                 0.0727          81526    CO
# 255         255                 0.0425          96704    HI
# 256         256                 0.0625          60111    IL
# 257         257                 0.0710          62025    IL
#
#      to_postcode_ taxrate
# 0                   99927
# 1                   19980
# 2                   99840
# 3                   99832
# 4                   80135
# ..                    ...
# 253                 81521
# ...

# %%
pd.read_csv('TAXRATES1.csv') #row skip ka liya use
# Out:
#    Unnamed: 0 State ZipCode      TaxRegionName  StateRate  \
# 0           0    AK     one  ANCHORAGE BOROUGH        0.0
# 1           1    AK     one  ANCHORAGE BOROUGH        0.0
# 2           2    AK     two  ANCHORAGE BOROUGH        0.0
# 3           3    AK     two  ANCHORAGE BOROUGH        NaN
#
#    EstimatedCombinedRate  EstimatedCountyRate  EstimatedCityRate  \
# 0                    0.0                  0.0                NaN
# 1                    NaN                  0.0                0.0
# 2                    0.0                  NaN                0.0
# 3                    0.0                  0.0                0.0
#
#    EstimatedSpecialRate  RiskLevel
# 0                   0.0          1
# 1                   0.0          2
# 2                   NaN          3
# 3                   0.0          4

# %%
pd.read_csv('TAXRATES1.csv', skiprows=[1]) #row skip ka liya use
# Out:
#    Unnamed: 0 State ZipCode      TaxRegionName  StateRate  \
# 0           1    AK     one  ANCHORAGE BOROUGH        0.0
# 1           2    AK     two  ANCHORAGE BOROUGH        0.0
# 2           3    AK     two  ANCHORAGE BOROUGH        NaN
#
#    EstimatedCombinedRate  EstimatedCountyRate  EstimatedCityRate  \
# 0                    NaN                  0.0                  0
# 1                    0.0                  NaN                  0
# 2                    0.0                  0.0                  0
#
#    EstimatedSpecialRate  RiskLevel
# 0                   0.0          2
# 1                   NaN          3
# 2                   0.0          4

# %%
pd.read_csv('TAXRATES1.csv', skipfooter=1) #row skip ka liya use
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   """Entry point for launching an IPython kernel.
#    Unnamed: 0 State ZipCode      TaxRegionName  StateRate  \
# 0           0    AK     one  ANCHORAGE BOROUGH          0
# 1           1    AK     one  ANCHORAGE BOROUGH          0
# 2           2    AK     two  ANCHORAGE BOROUGH          0
#
#    EstimatedCombinedRate  EstimatedCountyRate  EstimatedCityRate  \
# 0                    0.0                  0.0                NaN
# 1                    NaN                  0.0                0.0
# 2                    0.0                  NaN                0.0
#
#    EstimatedSpecialRate  RiskLevel
# 0                   0.0          1
# 1                   0.0          2
# 2                   NaN          3

# %%
with open('data.csv') as f:
    lines = list(csv.reader(f))
lines #with open is a dynamic
# Out:
# [['Course', 'Students', 'location', 'Faculty Teachers'],
#  ['AI', '3000', 'Saylani HO', '30'],
#  ['CNC', '1056', 'Saylani Gulshan', '14'],
#  ['Block chain', '1307', 'Adamjee', '12'],
#  ['IOT', '2000', 'Bahria', '16']]

# %%
header, values = lines[0], lines[1:]
data_dict = {h: v for h, v in zip(header, zip(*values))}
data_dict
# Out:
# {'Course': ('AI', 'CNC', 'Block chain', 'IOT'),
#  'Students': ('3000', '1056', '1307', '2000'),
#  'location': ('Saylani HO', 'Saylani Gulshan', 'Adamjee', 'Bahria'),
#  'Faculty Teachers': ('30', '14', '12', '16')}

# %%
for h,v in zip(header,zip(*values)):
    print(h) #zip sa course aur course ka tuple aye ga 
    print(v)
# Out:
# Course
# ('AI', 'CNC', 'Block chain', 'IOT')
# Students
# ('3000', '1056', '1307', '2000')
# location
# ('Saylani HO', 'Saylani Gulshan', 'Adamjee', 'Bahria')
# Faculty Teachers
# ('30', '14', '12', '16')

# %%
for h,v in zip(header,values):
    print(h)
    print(v) #zip nhi kiya values tu wo index wise laye ga
# Out:
# Course
# ['AI', '3000', 'Saylani HO', '30']
# Students
# ['CNC', '1056', 'Saylani Gulshan', '14']
# location
# ['Block chain', '1307', 'Adamjee', '12']
# Faculty Teachers
# ['IOT', '2000', 'Bahria', '16']

# %%
x=[1,2,3,4,5,6]
y=[7,8,9,10,11,12]
a=[3,6,9,12,15,18]
z=zip(x,y,a)

# %%
for val in z:
    print(val)
# Out:
# (1, 7, 3)
# (2, 8, 6)
# (3, 9, 9)
# (4, 10, 12)
# (5, 11, 15)
# (6, 12, 18)

# %%
for i,j,k in z:
    print(i,j,k)
# Out:
# 1 7 3
# 2 8 6
# 3 9 9
# 4 10 12
# 5 11 15
# 6 12 18

# %%
x=['mansoor','shakeeb'] #packing

# %%
t,s=x #unpacking

# %%
t
# Out:
# 'mansoor'

# %%
s
# Out:
# 'shakeeb'

# %%
obj = """
{"name": "Wes",
"places_lived": ["United States", "Spain", "Germany"],
"pet": null,
"siblings": [{"name": "Scott", "age": 30, "pets": ["Zeus", "Zuko"]},
{"name": "Katie", "age": 38,
"pets": ["Sixes", "Stache", "Cisco"]}]
}
"""
print(obj) #json direct read nhi hoga python ma
# Out:
# {"name": "Wes",
# "places_lived": ["United States", "Spain", "Germany"],
# "pet": null,
# "siblings": [{"name": "Scott", "age": 30, "pets": ["Zeus", "Zuko"]},
# {"name": "Katie", "age": 38,
# "pets": ["Sixes", "Stache", "Cisco"]}]
# }

# %%
type(obj) #abhi dic ma read nhi kar pa raha hoga
# Out:
# str

# %%
import json
result = json.loads(obj) #agr type str ha tu dic kardaga 
result1=json.dumps(obj) # agar type jsno to string
result1
# Out:
# '"\\n{\\"name\\": \\"Wes\\",\\n\\"places_lived\\": [\\"United States\\", \\"Spain\\", \\"Germany\\"],\\n\\"pet\\": null,\\n\\"siblings\\": [{\\"name\\": \\"Scott\\", \\"age\\": 30, \\"pets\\": [\\"Zeus\\", \\"Zuko\\"]},\\n{\\"name\\": \\"Katie\\", \\"age\\": 38,\\n\\"pets\\": [\\"Sixes\\", \\"Stache\\", \\"Cisco\\"]}]\\n}\\n"'

# %%
type(result)
# Out:
# dict

# %%
result
# Out:
# {'name': 'Wes',
#  'places_lived': ['United States', 'Spain', 'Germany'],
#  'pet': None,
#  'siblings': [{'name': 'Scott', 'age': 30, 'pets': ['Zeus', 'Zuko']},
#   {'name': 'Katie', 'age': 38, 'pets': ['Sixes', 'Stache', 'Cisco']}]}

# %%
result['siblings']
# Out:
# [{'name': 'Scott', 'age': 30, 'pets': ['Zeus', 'Zuko']},
#  {'name': 'Katie', 'age': 38, 'pets': ['Sixes', 'Stache', 'Cisco']}]

# %%
siblings = pd.DataFrame(result['siblings'], columns=['name', 'age'])
siblings
# Out:
#     name  age
# 0  Scott   30
# 1  Katie   38

# %%
txt = pd.read_table('TAXRATES1.csv')
txt #
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: read_table is deprecated, use read_csv instead, passing sep='\t'.
#   """Entry point for launching an IPython kernel.
#   ,State,ZipCode,TaxRegionName,StateRate,EstimatedCombinedRate,EstimatedCountyRate,EstimatedCityRate,EstimatedSpecialRate,RiskLevel
# 0              0,AK,one,ANCHORAGE BOROUGH,0,0,0,,0,1
# 1              1,AK,one,ANCHORAGE BOROUGH,0,,0,0,0,2
# 2               2,AK,two,ANCHORAGE BOROUGH,0,0,,0,,3
# 3              3,AK,two,ANCHORAGE BOROUGH,,0,0,0,0,4

# %%
fwf = pd.read_fwf('TAXRATES1.csv') #fwf jasi file hogi wasi read karaga

# %%
fwf
# Out:
#   ,State,ZipCode,TaxRegionName,StateRate,EstimatedCombinedRate,EstimatedCountyRate,EstimatedCityRate,EstimatedSpecialRate,RiskLevel
# 0              0,AK,one,ANCHORAGE BOROUGH,0,0,0,,0,1
# 1              1,AK,one,ANCHORAGE BOROUGH,0,,0,0,0,2
# 2               2,AK,two,ANCHORAGE BOROUGH,0,0,,0,,3
# 3              3,AK,two,ANCHORAGE BOROUGH,,0,0,0,0,4

# %%
clip = pd.read_clipboard()
clip
# Out:
#    0  0.1  AK  one  ANCHORAGE BOROUGH  0.0  0.0.1  0.0.2  NaN  0.0.3    1
# 0  1    1  AK  one  ANCHORAGE BOROUGH  0.0    NaN    0.0  0.0    0.0  2.0
# 1  2    2  AK  two  ANCHORAGE BOROUGH  0.0    0.0    NaN  0.0    NaN  3.0
# 2  3    3  AK  two  ANCHORAGE BOROUGH  NaN    0.0    0.0  0.0    0.0  NaN

# %%
pd.read_excel('test2.xlsx')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-67-fa10276656c9> in <module>
# ----> 1 pd.read_excel('test2.xlsx')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     186                 else:
#     187                     kwargs[new_arg_name] = new_arg_value
# --> 188             return func(*args, **kwargs)
#     189         return wrapper
#     190     return _deprecate_kwarg
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     186                 else:
#     187                     kwargs[new_arg_name] = new_arg_value
# --> 188             return func(*args, **kwargs)
#     189         return wrapper
#     190     return _deprecate_kwarg
#
# ...

# %%
df = pd.DataFrame([[1, 1.0, 'a']], columns=['x', 'y', 'z'])
df
# Out:
#    x    y  z
# 0  1  1.0  a

# %%
df.to_hdf('./stored.h5','data')
df.to_csv('abcd.csv') #hdf ko baar baar load karka dakhna hoga csv excel ma bi khol jati ha

# %%
reread=pd.read_hdf('stored.h5')
reread
# Out:
#    x    y  z
# 0  1  1.0  a

# %%
f=pd.read_csv('abcd.csv')
f
# Out:
#    Unnamed: 0  x    y  z
# 0           0  1  1.0  a

# %%
htmlReader = pd.read_html('index.html')
htmlReader #pandas website sa table data utata ha
# Out:
# [     Company    Contact  Country
#  0    Alfreds      Maria  Germany
#  1     Centro  Francisco   Mexico
#  2      Ernst     Roland  Austria
#  3     Island      Helen       UK
#  4   Laughing      Yoshi   Canada
#  5  Magazzini   Giovanni    Italy]

# %%
# %load data.json
{"columns":["col 1","col 2"],
  "index":["row 1","row 2"],
  "data":[["a","b"],["c","d"]]}
# Out:
# {'columns': ['col 1', 'col 2'],
#  'index': ['row 1', 'row 2'],
#  'data': [['a', 'b'], ['c', 'd']]}

# %%
readJson = pd.read_json('data.json')
readJson
# Out:
#   columns  index    data
# 0   col 1  row 1  [a, b]
# 1   col 2  row 2  [c, d]

# %%
htmlReader = pd.read_html('index.html')
pd.DataFrame(htmlReader[0])#pandas website sa table data utata ha html ka read ma zero dana hoga
# Out:
#      Company    Contact  Country
# 0    Alfreds      Maria  Germany
# 1     Centro  Francisco   Mexico
# 2      Ernst     Roland  Austria
# 3     Island      Helen       UK
# 4   Laughing      Yoshi   Canada
# 5  Magazzini   Giovanni    Italy

# %%
tables = pd.read_html('https://www.fdic.gov/bank/individual/failed/banklist.html')
tables
# Out:
# [                                           Bank Name        City  ST   CERT  \
#  0                                      Resolute Bank      Maumee  OH  58317
#  1                        Louisa Community Bank, Inc.      Louisa  KY  58112
#  2                               The Enloe State Bank      Cooper  TX  10716
#  3                Washington Federal Bank for Savings     Chicago  IL  30570
#  4    The Farmers and Merchants State Bank of Argonia     Argonia  KS  17719
#  ..                                               ...         ...  ..    ...
#  553                               Superior Bank, FSB    Hinsdale  IL  32646
#  554                              Malta National Bank       Malta  OH   6629
#  555                  First Alliance Bank & Trust Co.  Manchester  NH  34264
#  556                National State Bank of Metropolis  Metropolis  IL   3815
#  557                                 Bank of Honolulu    Honolulu  HI  21029
#
# ...

# %%
pd.DataFrame(tables[0]) #html sa data 0 index pa aye ga
# Out:
#                                            Bank Name        City  ST   CERT  \
# 0                                      Resolute Bank      Maumee  OH  58317
# 1                        Louisa Community Bank, Inc.      Louisa  KY  58112
# 2                               The Enloe State Bank      Cooper  TX  10716
# 3                Washington Federal Bank for Savings     Chicago  IL  30570
# 4    The Farmers and Merchants State Bank of Argonia     Argonia  KS  17719
# ..                                               ...         ...  ..    ...
# 553                               Superior Bank, FSB    Hinsdale  IL  32646
# 554                              Malta National Bank       Malta  OH   6629
# 555                  First Alliance Bank & Trust Co.  Manchester  NH  34264
# 556                National State Bank of Metropolis  Metropolis  IL   3815
# 557                                 Bank of Honolulu    Honolulu  HI  21029
#
# ...

# %%
len(tables)
# Out:
# 1

# %%
f=tables[0]

# %%
f.head()
# Out:
#                                          Bank Name     City  ST   CERT  \
# 0                                    Resolute Bank   Maumee  OH  58317
# 1                      Louisa Community Bank, Inc.   Louisa  KY  58112
# 2                             The Enloe State Bank   Cooper  TX  10716
# 3              Washington Federal Bank for Savings  Chicago  IL  30570
# 4  The Farmers and Merchants State Bank of Argonia  Argonia  KS  17719
#
#                Acquiring Institution       Closing Date      Updated Date
# 0                 Buckeye State Bank   October 25, 2019  October 25, 2019
# 1  Kentucky Farmers Bank Corporation   October 25, 2019  October 25, 2019
# 2                 Legend Bank, N. A.       May 31, 2019   August 22, 2019
# 3                 Royal Savings Bank  December 15, 2017     July 24, 2019
# 4                        Conway Bank   October 13, 2017   August 12, 2019

# %%
close_timestamps = pd.to_datetime(f['Closing Date'])
close_timestamps
# Out:
# 0     2019-10-25
# 1     2019-10-25
# 2     2019-05-31
# 3     2017-12-15
# 4     2017-10-13
#          ...
# 553   2001-07-27
# 554   2001-05-03
# 555   2001-02-02
# 556   2000-12-14
# 557   2000-10-13
# Name: Closing Date, Length: 558, dtype: datetime64[ns]

# %%
dateCount = close_timestamps.dt.date.value_counts() #Count Dates in this column
dayCount = close_timestamps.dt.day.value_counts() #Count Days in this column
monthCount = close_timestamps.dt.month.value_counts() #Count months in this column
yearCount = close_timestamps.dt.year.value_counts() #Count years in this column
dateCount
# Out:
# 2009-10-30    9
# 2010-08-20    8
# 2010-04-16    8
# 2009-07-24    7
# 2009-12-18    7
#              ..
# 2000-12-14    1
# 2011-03-25    1
# 2007-09-28    1
# 2015-01-23    1
# 2013-03-08    1
# Name: Closing Date, Length: 253, dtype: int64

# %%
dayCount
# Out:
# 23    31
# 30    30
# 19    30
# 20    27
# 17    23
#       ..
# 12    10
# 9     10
# 31     9
# 1      8
# 3      4
# Name: Closing Date, Length: 31, dtype: int64

# %%
monthCount
# Out:
# 7     74
# 10    61
# 4     59
# 1     51
# 5     44
#       ..
# 3     40
# 9     38
# 6     36
# 12    35
# 11    35
# Name: Closing Date, Length: 12, dtype: int64

# %%
from lxml import objectify
parsed = objectify.parse(open('abc.xml'))
root = parsed.getroot() #string ko object ma convert
root
# Out:
# <Element INDICATOR at 0x1f42660fc48>

# %%
data = []
skip_fields = ['PARENT_SEQ', 'INDICATOR_SEQ',
'DESIRED_CHANGE', 'DECIMAL_PLACES']
for elt in root.INDICATOR:
    el_data = {}
    for child in elt.getchildren():
        if child.tag in skip_fields:
            continue
#         print(child.tag)
#         print(child.pyval)
        el_data[child.tag] = child.pyval
    data.append(el_data)

# %%
data
# Out:
# [{'AGENCY_NAME': 'Metro-North Railroad',
#   'INDICATOR_NAME': 'Escalator Availability',
#   'DESCRIPTION': 'Percent of the time that escalators are operational\nsystemwide. The availability rate is based on physical observations performed\nthe morning of regular business days only. This is a new indicator the agency\nbegan reporting in 2009.',
#   'PERIOD_YEAR': 2011,
#   'PERIOD_MONTH': 12,
#   'CATEGORY': 'Service Indicators',
#   'FREQUENCY': 'M',
#   'INDICATOR_UNIT': '%',
#   'YTD_TARGET': 97.0,
#   'YTD_ACTUAL': '',
#   'MONTHLY_TARGET': 97.0,
#   'MONTHLY_ACTUAL': ''}]

# %%
import requests #request bi different tyoe ki hoti ha #json haar language pa get kar sakta ho

# %%
url = 'https://api.github.com/repos/pandas-dev/pandas/issues'
resp = requests.get(url)
resp #means respone mil gaya
# Out:
# <Response [200]>

# %%
data = resp.json()
data
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29235',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29235/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29235/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29235/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/29235',
#   'id': 512820850,
#   'node_id': 'MDU6SXNzdWU1MTI4MjA4NTA=',
#   'number': 29235,
#   'title': 'Categories reordered to alphabetical when plotting histograms',
#   'user': {'login': 'dmey',
#    'id': 26348635,
#    'node_id': 'MDQ6VXNlcjI2MzQ4NjM1',
#    'avatar_url': 'https://avatars2.githubusercontent.com/u/26348635?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dmey',
#    'html_url': 'https://github.com/dmey',
# ...

# %%
data[0]['title']
# Out:
# 'Categories reordered to alphabetical when plotting histograms'

# %%
issues = pd.DataFrame(data, columns=['number', 'title','labels', 'state'])
issues
# Out:
#     number                                              title  \
# 0    29235  Categories reordered to alphabetical when plot...
# 1    29234                     BUG: PeriodEngine doesn't work
# 2    29233                read_csv encode operation on source
# 3    29232                             CLN: assorted cleanups
# 4    29231  numpy.asarray() removes fill value from Pandas...
# ..     ...                                                ...
# 25   29192                      Removed generate_bins_generic
# 26   29191                   Asset Frame with duplicate index
# 27   29190  BUG: Preserve key order when using loc on Mult...
# 28   29189  groupby error when grouping by float index wit...
# 29   29188  Fix mypy error in pandas/tests.indexes.test_ba...
#
#                                                labels state
# 0                                                  []  open
# 1                                                  []  open
# ...

# %%
import pandas as pd

# %%
import requests

# %%
url='https://api.github.com/repos/pandas-dev/pandas/issues?fbclid=IwAR3uCznsk5Ez8JjHdiMzaG_Im8HEcYachihsiVMi31oi3qfk0jNfWtNDCd8'
r=requests.get(url)
r
# Out:
# <Response [200]>

# %%
data=r.json()
data
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29334',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29334/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29334/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/29334/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/29334',
#   'id': 516453516,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0MzM1NzA4NDg0',
#   'number': 29334,
#   'title': 'BUG: assignment to multiple columns when some column do not exist',
#   'user': {'login': 'howsiwei',
#    'id': 3800802,
#    'node_id': 'MDQ6VXNlcjM4MDA4MDI=',
#    'avatar_url': 'https://avatars1.githubusercontent.com/u/3800802?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/howsiwei',
#    'html_url': 'https://github.com/howsiwei',
# ...

# %%
i=pd.DataFrame(data)
i
# Out:
#    assignee assignees author_association  \
# 0      None        []        CONTRIBUTOR
# 1      None        []             MEMBER
# 2      None        []             MEMBER
# 3      None        []             MEMBER
# 4      None        []             MEMBER
# 5      None        []               NONE
# 6      None        []               NONE
# 7      None        []             MEMBER
# 8      None        []               NONE
# 9      None        []             MEMBER
# 10     None        []               NONE
# 11     None        []             MEMBER
# 12     None        []               NONE
# 13     None        []               NONE
# 14     None        []        CONTRIBUTOR
# 15     None        []               NONE
# 16     None        []             MEMBER
# 17     None        []             MEMBER
# 18     None        []        CONTRIBUTOR
# 19     None        []             MEMBER
# 20     None        []             MEMBER
# 21     None        []             MEMBER
# ...

# %%
i.body
# Out:
# 0     - [x] closes #13658\r\n- [x] tests added / pas...
# 1     Separating these out from the non-CLN work goi...
# 2     ATM all places where we use `maybe_upcast_putm...
# 3     Narrowing down the set of cases where we have ...
# 4     Noticed this when rebuilding dev environment f...
# 5     - [✓] closes #29325\r\n- [✓] whatsnew: the abo...
# 6     Docstring for TO_CSV from my repo\r\n\r\n>    ...
# 7     When I run `mypy pandas` locally I get a handf...
# 8     #### Code Sample, a copy-pastable example if p...
# 9     xref: https://github.com/pandas-dev/pandas/iss...
# 10    #### Code Sample\r\n\r\n```python\r\n\r\ndf = ...
# 11    cc @mroeschke since a lot of this touches libw...
# 12    #### Code Sample, a copy-pastable example if p...
# 13    #### Problem description\r\n\r\nI am using the...
# 14    - [x] closes  #26632\r\n- [x] tests added / pa...
# 15    Running the following:\r\n```scripts/validate_...
# 16
# 17    From our benchmarks (`GetLoc` class in https:/...
# ...
